# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
import cPickle as pickle
import html5lib
import os
import ipyparallel as ipp

from bs4 import BeautifulSoup as bs
from urllib2 import urlopen
from urllib2 import Request
from urllib2 import URLError

reload(sys)
sys.setdefaultencoding('utf-8')
sys.setrecursionlimit(50000)

# %matplotlib inline

# %% [markdown]
# # Vamos a ir abriendo archivo por archivo y concatenando todos.

# %%
a1 = pickle.load(open("../../../../datos/save1.p","rb"))

# %%
a1.head(10)
# Out:
#                                          id  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2
# 1  a205c53378e7879cf7519659317fb410c060d20e
# 2  9446052c949050359fb08b9f1ba83ba2eaa20c99
# 3  4d3b492ed5f9c74cdf33b56b98328e5c950e3f9c
# 4  61f3789618edabeaa7b5fc06ff36112f8a06557f
# 5  e842ed22eac89b9bffff146377abfd5bceb0b0cd
# 6  4dcfa9a54bdd18cd5438221c6dcfa94738c11c40
# 7  0f0e301809a14b8c069b267fa1c56a3b5ec35d9e
# 8  681ee228d423d9f806d227388bfb7d42e1ac14c9
# 9  fbad0166fa6df0784af5a9210b09ca34ff6e82a1
#
#                                        properati_url  rooms  ambientes  \
# 0  http://www.properati.com.ar/udh_venta_casa_mer...    NaN        NaN
# 1  http://www.properati.com.ar/20hi_venta_casa_me...    3.0        4.0
# 2  http://www.properati.com.ar/4m4m_venta_casa_ma...    5.0        3.0
# 3  http://www.properati.com.ar/518a_venta_departa...    2.0        2.0
# 4  http://www.properati.com.ar/59ec_venta_departa...    2.0        NaN
# ...

# %%
a1.tail(10)
# Out:
#                                             id  \
# 4990  b33efcfeae0ba944929ae56050278834b12b01ab
# 4991  de59747431c9685de8159563a661400987661264
# 4992  6fd30f75b0c0a4e1087a9dd3b65866c0a4138773
# 4993  2b46400cf19f94bfad89b77fed354dba7b7c04e6
# 4994  55a4e98fe760ae8f4d84257762067a6faa1a32e3
# 4995  4eac3869985a42fa45b6354f6e590fa28fb3d0ec
# 4996  62646eb4e351d40e486aba099ebef8979bf6a317
# 4997  c757edc5735b842e24a7ca25b7a7171256c64f3f
# 4998  43dd0937a5aaa6167f4271d2db91340b9df9c4ef
# 4999  d98c8f78543082c7744d405b77b9a0953c80da2c
#
#                                           properati_url  rooms  ambientes  \
# 4990  http://www.properati.com.ar/od2g_venta_departa...    1.0        2.0
# 4991  http://www.properati.com.ar/od2h_venta_departa...    3.0        3.0
# 4992  http://www.properati.com.ar/od2n_venta_departa...    3.0        NaN
# 4993  http://www.properati.com.ar/od2o_venta_departa...    4.0        2.0
# ...

# %%
a2 = pickle.load(open("../../../datos/save2.p","rb"))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-84de0fc2d096> in <module>()
# ----> 1 a2 = pickle.load(open("../../../datos/save2.p","rb"))
#
# IOError: [Errno 2] No such file or directory: '../../../datos/save2.p'

# %%
a2.head(10)
# Out:
#                                              id  \
# 25706  d9a89ff62fbf3362a449ec2c75169b5340f12270
# 25709  3f1763ab687970d83115e758a7092203a2c048be
# 25710  db3a298d5a6f8f1b39c14337718fb208c95c20ca
# 25711  2c336e6e1dadcd7685a8498fd80a07b0723ad7e7
# 25712  798e48b4a75e4c0fa02606521f772dd74b245303
# 25713  1d84eb3e9740c526cee4070ba4d7095ac85bb804
# 25714  043d5bd932a036bb0e9caca7557268cce00eca25
# 25715  bbfd6b122eaa522069c7271593e90b1a97d52ec0
# 25716  e39c7cca02e8f9cb37a49db6dc42a4ac400f0e4a
# 25717  10b653324fa51cb21367a4970b255e2d38761ef1
#
#                                              description  \
# 25706  Excelente ubicación a sólo 300 metros del Mar....
# 25709  EN VENTA DUPLEX 4 AMBIENTES CON COCHERA, SAN M...
# 25710  Venta de Casa 4 AMBIENTES en Hurlingham.Cocina...
# 25711  Venta de Departamento 2 AMBIENTES en Almagro-D...
# 25712  Venta de Departamento 3 AMBIENTES en Centro / ...
# 25713  Venta de Departamento 3 AMBIENTES en Centro / ...
# ...

# %%
a2.tail(10)
# Out:
#                                              id  \
# 50442  0794d725201450a562e46f0245c60c0b695b08cf
# 50443  85bfd73690a8de51573b64de7837a238575affa4
# 50444  f76d2e87c0db616ba7dd5223e6d5184eba3fa87b
# 50447  44d8770facceb92bf03be94803974ba8c122a4f7
# 50448  dfa9f6422d68895553c6913e925e4480676bd5f5
# 50449  770d25757ef02559c58bbbec8876bf533bde8126
# 50450  67e811bdb2e425a4050405a857b65e22d6d36a63
# 50451  722e320feb5f2658fc42cf1a4b5fb7a72b0d6f71
# 50452  fdbdea14e00645e846233b6e3aa0db2942fc9355
# 50453  23c01d1f4fb1d050a6a51204341c12f99b7d0ea4
#
#                                              description  \
# 50442  EXCELENTE ***CASA EN B* LOS MANANTIALES en  VI...
# 50443  VENTA Dpto 2 AMB AMPLIO-RECICLADO de 1º CALIDA...
# 50444  En Edificio de 6 años, contamos con departamen...
# 50447  Casa tipo,original en óptimo estado de conserv...
# 50448  Hermoso chalet en esquina en pleno corazón de ...
# 50449                Casa en Venta de 2 dorm. en Cordoba
# ...

# %%
a3 = pickle.load(open("../../../datos/save4.p","rb"))

# %%
a3.head(10)
# Out:
#                                              id  \
# 50454  5fb774a932f4f4e2a2426c1c33c9160bde4e8a98
# 50455  3b3452d1ed6c19c51a2dd5ee89adbf795c3a7bc3
# 50456  1a591a35e6ce970cb4e319c459a8b4f6c64253e3
# 50457  5010d700ddb97cfb027049738f137764d04e681f
# 50460  3916179c1eacc9586f2b78b335ae940861a228af
# 50461  94947ac1dff366e18bd3e5127e98bb14cffe4b14
# 50462  8ab6525e2e057abc20530709e178ea4e783da63a
# 50463  4427af90899f9c7b7d7de48527e515ef4229e48c
# 50464  123d8fa630eb14409cb701df3604c08cda857d9c
# 50465  8a95217b5f353f43f032a8ba63c82c495fa13665
#
#                                              description  \
# 50454  Venta de excelente Casa  en BocaSin expensas, ...
# 50455  2 AMBIENTES. INTERNO. 27 M2. TODO A NUEVO. BAÑ...
# 50456  Saravì 3030, La Lonja, Pilar. Altura Km 47,5 d...
# 50457  VENTA CASA 5 AMBIENTES CABALLITOCARACTERÍSTICA...
# 50460  LOCALEXCELENTE LOCAL A LA CALLE , CON AMPLIOS ...
# 50461  Venta de Departamento 4 AMBIENTES en Vicente L...
# ...

# %%
a3.tail(10)
# Out:
#                                              id  \
# 76203  cff0333adee80dbdff5564d9ff08114d6e300d2f
# 76204  24003357195de3b88636d83d72a5456ab9659d0c
# 76205  5290310ee8647b000ea20e2435634620eea4b9c0
# 76206  4edf539ee728bb7fb63c74854a9fd3098ea18e66
# 76207  bb23c80448dca5ae40699a3cb32d0eef11ced33b
# 76208  068121a82aca590f1cd21dff3fe9f834267a083b
# 76211  45da1d59750869a70aa2c94be01e7f8194a5019f
# 76212  d9419e8aba556186434fcf2db80c0a950786c176
# 76213  2ce9c8439368398893752980674cad00cd30928d
# 76214  2a0c9e3d41ff823c9db08cc7bdee82853bcad7be
#
#                                              description  \
# 76203  SE VENDE CASA EN CALLE TUCUMAN AL 300, BARRIO ...
# 76204  Unidades de categoria a metros del Subte B (Es...
# 76205  Semipiso de 1 Ambiente a Estrenar . Super lumi...
# 76206  DPTO 3ºP UN DORMITORIO AMPLIO DE 4X 3,50 M CON...
# 76207  Semipiso de 2 Ambientes a Estrenar . Super lum...
# 76208  PH EN DOS PLANTAS .PRIMER PISO POR ESCALERA AL...
# ...

# %%
a4 = pickle.load(open("../../../datos/save5.p","rb"))

# %%
a4.head(10)
# Out:
#                                              id  \
# 76215  913e17032bacb9368d5119e7b5f9794a4d584e76
# 76216  66e599e36644c2d043d46aee40f9aafa5c9c724c
# 76217  55afaf8a5ed263f68f9bda228bae909b2e0df674
# 76218  d173211e6a400f148b874e26c738afb02b89e3f8
# 76219  85881c6c871ea60ca6ca569d06eade08647a44f9
# 76220  3c0e65ac76b4902ec89d78ca246bc6233dc587f8
# 76221  440b1a1a9d9cba5a14ca5237b50e1f9627db3da5
# 76222  647a710cc9615ba16b92f175cf59aa790765416c
# 76223  b7ec301830bd04950ba8bf4a0bed7e651650592f
# 76224  de6c3a7fc9fac6506affa8d4abc31437976c0b0c
#
#                                              description  \
# 76215   EXCELENTE OPORTUNIDAD ...CASA DE 20 AÑOS, BIE...
# 76216  Solares del Talar es un barrio que tiene una g...
# 76217   ACEPTA DEPTO DE 1 O 2 AMBIENTES HASTA 3 COMO ...
# 76218  Semipiso de 2 Ambientes a Estrenar . Super lum...
# 76219  Edificio de 7 pisos en el centro de Wilde. Con...
# 76220  Edificio de 7 pisos en el centro de Wilde. Con...
# ...

# %%
a4.tail(10)
# Out:
#                                              id  \
# 99196  c3d3411dbc1bb8a420ea8dc0c763782994040a60
# 99197  04fcce70fe790c172f4543179ea9bbaf62c8e846
# 99198  6e5b31d785c7b6640053dfc551179e1664c2cdbd
# 99199  76438ce258c905f95232a7a7b9c60ebb579a5436
# 99200  dc5356f26909f37ab25d07cc2bbc9f0b32e223fd
# 99201  cb12896ce3edb22911811b23313d4a65f29c5a50
# 99202  1e321bcc252fcabadb08572d0cad6cadbfea65df
# 99203  268e3bc361d56f8a6cb61db24526d7202cb539af
# 99204  40987befcdd64e2c031f9d6e76eea3445b76ac10
# 99205  fa357563809b6cc82eb13c72cb4b8ef6bc474efe
#
#                                              description  \
# 99196  CÓD: CDTO16Excelente complejo en Villa Carlos ...
# 99197  CÓD: CCP172Hermosa casa en Costa Azul, con bue...
# 99198  CÓD: DPT116Dos departamentos en el mismo edifi...
# 99199  Chalet + Dpto independienteExcelente oportunid...
# 99200  MENDOZA BIENES RAICES VENDE:CASA de 100m2 a es...
# 99201  APTA CREDITOPosee 3 Dormitorios cada uno con s...
# ...

# %%
a5 = pickle.load(open("../../../datos/save6.p","rb"))

# %%
a5.head(10)
# Out:
#                                              id  \
# 99206  a067c0bdd4e439e8ecc51c729e4a35f3957f0874
# 99207  aabcf11c2842a161e1822dbf0f49798a3805687a
# 99208  7542c0d9ad4d8b0c213bdd1ba358135f3b4febfb
# 99209  e9b0d147c2b17c2dc76d88cc9af91a2e6d424cd5
# 99210  db8be4af3266af3e898fa0f4f1c9650586808ec7
# 99211  958eb7d8c84b8d5fe0f0f41d563d47a1c6fcf15d
# 99212  99860460a023bffb40327755b14058bc45add4c8
# 99213  5c8c17b0a37d77366fe6ede46c84bbc57b9f3842
# 99214  8f2adefb49464c696a5c4524899996bd581f91a1
# 99215  e7a1769fd88b6f43295888eb37c33f54b23302c9
#
#                                              description  \
# 99206  CÓD: CCP188Casa San Antonio Consta de: 450 m2 ...
# 99207  CÓD: DPT164Hermoso complejo de departamentos a...
# 99208  CÓD: DPT130Dos departamentos en el mismo terre...
# 99209  CÓD: CCP187APTO CRÉDITOCasa ubicada en Tanti s...
# 99210  CÓD: CCP192APTA CRÉDITOCasa ubicada en TantiCo...
# 99211  DEPARTAMENTO DE DOS AMBIENTES A LA CALLE CON B...
# ...

# %%
a5.tail(10)
# Out:
#                                               id  \
# 121825  965b12fbb420a51066b6efbd15982e45d3f65777
# 121826  d764320c1e457af400698f53846c7def41168503
# 121827  ce6791f31b10d63a74e7293364cba2fa7cf6bbcb
# 121829  4dd3276e450d2c8a339ae443a219d7a79c5c4326
# 121830  114e7bf420a9baeb93577622a1e671fd9728023c
# 121831  36e63da55517a8d26c6fbf7ea7bcaba80121a9b9
# 121832  962a28f9cb2255b7c84560d4e73f50a09fb14df5
# 121834  48f5785e10e384e3af1bd43b3ec037dcaaa89c1d
# 121835  fcebe828e51983f9027a9b5c5cc64963ffb8a7c0
# 121836  72eb2da66fa7538da17254626a3b3dc5452ed9c1
#
#                                               description  \
# 121825  CODIGO:  ubicado en: CENTENARIO -  Publicado p...
# 121826  CODIGO: 735-Tucuman 2192 ubicado en: Tucuman 2...
# 121827  CODIGO: 486-501 ubicado en: Presidente Perón 2...
# 121829  CODIGO: 512-1769 ubicado en: QUIRNO 191 3º "C"...
# 121830  CODIGO: 452-553 ubicado en: AVENIDA 4 Y PASEO ...
# 121831  CODIGO: 2388-LLG1121 ubicado en: Carlos Pelleg...
# ...

# %%
a6 = pickle.load(open("../../../datos/save7.p","rb"))

# %%
a6.head(10)
# Out:
#                                               id  \
# 121837  c091c0ab2195aede331252ff6c171e3d94bea53a
# 121838  0501021c12742b0b754d8558945a5755e3a6d496
# 121839  f1595daea16c7aa1c7ad6dd4e75fa642b5888027
# 121840  88de498bd54a013248e6f90a15d7802f9e2653d8
# 121841  21b73e93b1e40c68dca7b14f05765ee9bab23683
# 121843  ed200eb37094b86744fb9a5a00f844962a156265
# 121844  88c74309d425a433eb16923b0c65a0ec8a9ac80a
# 121845  bc1d473757017d205fdf0b7c34f4b20a853aad93
# 121846  5d82bcf02b41790c85c49662c565fa820ece5c01
# 121847  727e6fa2ce1c6382953349effc5adb87dfbead1a
#
#                                               description  \
# 121837  CODIGO:  ubicado en: Soldado de la Independenc...
# 121838  CODIGO: 19-AlessandriaI.I ubicado en: ROCA 622...
# 121839  CODIGO: 272-CO 1 ubicado en: RIO TERCERO -  Pu...
# 121840  La propiedad consta de: jardín al frete, coche...
# 121841  CODIGO: 3783-D027 ubicado en: OBISPO TREJO 113...
# 121843  CODIGO: 452-551 ubicado en: Avenida 4 y Paseo ...
# ...

# %%
a6.tail(11)
# Out:
#                                               id  \
# 145482  dec3cf7c89c02a59491cc06da78559a3201e3f90
# 145483  ae7965af1cfc25d9772b54ee8dc07e872d35dae2
# 145487  ebf551935f9210278171fb384bf14490f50f7833
# 145488  9b3df4b1bd6c438aa4eee0740b0d9bd23c9de0c4
# 145489  0162b4c481d4aad52d904d0e70879ea42b81d003
# 145491  bb2bfe2617f9e1d49bc5cd5aca80c014e178d366
# 145493  c2b5cccf9e89aa7fc1c770824ffe6847d3c30239
# 145494  99aa47567dc3939efa9f06e8eebe371fe3de6cbb
# 145495  40c68bc09fb895f89cd8825ad5746bcd47adfc5f
# 145496  4b5653ac3fdb693c26ed62550564050fa68829cd
# 145497  970f34941eef17c09a3cb850a60f5cee206688cb
#
#                                               description  \
# 145482  VENTA CHALET 5 AMBIENTES EN MARTINEZChalet des...
# 145483  Duplex en venta  de 3  dormitorios  con depend...
# 145487  EDIFICIO EN CONSTRUCCION, VENTA AL POZO, EXCEL...
# 145488  CHALET (tejas francesas)LOTE 8,66 x 43,30 mts....
# 145489  Excelente departamento a estrenar en Palermo H...
# ...

# %%
a7 = pickle.load(open("../../../datos/save8.p","rb"))

# %%
a7.head(10)
# Out:
#                                               id  \
# 145498  97710a3889f4254130d7fcccf2ce2f33444a8187
# 145499  0254759e16ef394fae3d9b8e475bccfcea94e8cd
# 145501  a52919638ba42865b38aee05c488203db075bc83
# 145503  680f5267641c05584d89315973a9c29816d14ab4
# 145504  89777799758fb6b4ad2ce17754ba82a83b8c79dd
# 145505  639668e8687e425c1a4a9e046e8b3d3d00467f29
# 145506  3367145a37ab535519babc3ff0f21717817dfe13
# 145507  ddf1864da4ad435e139510c3347030006d6e688b
# 145508  00d13144ded18a0c1e562532f068c89deefa753b
# 145509  963b0c0ce0047f7bc63a31cf9fdb23fdb5f8ecb2
#
#                                               description  \
# 145498  NO APTO CREDITO BANCARIO.CASA INTERNA nº: 3 (C...
# 145499  GURRUCHAGA 2200 e/ Paraguay y Charcas. Excelen...
# 145501  Se trata de un duplex de dos dormitorios y coc...
# 145503  Olguin Inmobiliaria VENDE !!!Vivienda de 2 pla...
# 145504  EDIFICIO EN CONSTRUCCION, VENTA AL POZO, EXCEL...
# 145505  Excelente Departamento de 3 ambientesReciclado...
# ...

# %%
a7.tail(10)
# Out:
#                                               id  \
# 151223  d096a76733589ee6c3583e8e49a3c18019fe81c6
# 151224  e6fbd3fda7ec426dd875fff94c2a31364b9ad74e
# 151226  e81227e9f99303cc293747d9eba108b276b616ae
# 151227  a9d7d63a22ff0e147ffe551a14f0299b8d5c1f2d
# 151228  f3021e7d4c250e540bfec6b55f254c7528a7a4b7
# 151229  495d73e958f68023454c849ad208bb95e4be3814
# 151230  5c2925e0e40dd1f4fc8e47a2450ff7f5ff5fc4dc
# 151231  cd1f0bd4718e5c73e8f146687b943de9a16ad335
# 151232  963e54118df4b7a247b06d68d09f76e41f9e1165
# 151233  8428b23da7d28df70ef3f298b7666c65c910f4cb
#
#                                               description  \
# 151223  HERMOSO MONOAMBIENTE, TODO LUZ DE 49M2, CON BA...
# 151224  Excelente departamento en impecable estado CON...
# 151226  Departamento con Pavimento, Argentina, Córdoba...
# 151227  En excelente zona del barrio de palermo, STUDI...
# 151228  EXC. DEPTO EN DUPLEX DE 4 AMB. CON COCHERA FIJ...
# 151229  Departamento ubicado en 4º piso, tipologia des...
# ...

# %%
a8 = pickle.load(open("../../../datos/save9.p","rb"))

# %%
a8.head(10)
# Out:
#                                               id  \
# 151234  be4dabd550a886daf204b120da9b17d6c4475ce7
# 151236  f2ea75230e081da156be0ae28bacd057852d0508
# 151237  c72eab85a184da7716b798f6776d7d51d8ae9648
# 151238  c1da22f2f1829ba17ad4ce501ee2747645ccb1a4
# 151239  4710843f60eebe0159ab91ee2a64cadef5f31377
# 151240  e5caeb11a109265b55359830ba5a3c9d2a473a04
# 151241  2e736f125f01b785b33df7496888dc32b7e1f1c2
# 151242  c0015d003a3f4fc15b0e3001fddbc700c4071a93
# 151243  1a4ae477aea9876cf266eaea1b790ad77204bd0a
# 151244  a29830fc18e54c6a2fa73d60a2012a33d821ab63
#
#                                               description  \
# 151234  EN UNO DE LOS BARRIOS MAS CONSOLIDADOS DEL COR...
# 151236  ESPECTACULAR Monoambiente a metros del subte B...
# 151237  CASA EN DOS PLANTAS CUENTA CON PB: 2 DORMITORI...
# 151238  Departamento con Corta distancia a pie centro,...
# 151239  Departamento 2 ambientes, excelente ubicación ...
# 151240  Sobre la calle Olavarria, a solo una cuadra de...
# ...

# %%
a8.tail(10)
# Out:
#                                               id  \
# 157299  bc1e7cdbd50e662eac3d97e9e68935e8bcda32ff
# 157300  8f041346465fa2e8874c65eacc4ae65aee53ae45
# 157301  8b857803c1c8dafb9eb2eb21b96c184f74507804
# 157302  f3b0dd3beca9d1d3677187f80772002ae703a77e
# 157304  778c7d6cdb94f023c7cb47c447a548a476fb60e6
# 157305  3e83067dc33160975173658c1a8fa72e043e6ada
# 157306  6c153b8fa3b0cb210368edd6d9fd642e07904a27
# 157307  92c8803803ecac723a36bfa089cf631c355532b7
# 157308  7b8ab0f585c0c6b65e4ad6e61adcd55b7f735838
# 157309  251c0379bc1aec06d2c447b7f2154f80f030a8d7
#
#                                               description  \
# 157299  Departamento de un dormitorio en el centro de ...
# 157300  Cada prefabricada a refaccionar, 3 dormitorios...
# 157301  Casa en venta Tortugas C.C. distribuida en dos...
# 157302  54 y 4Departamento de tres dormitorios en vent...
# 157304  DescripciónUna propiedad que se caracteriza po...
# 157305  4 DEPARTAMENTOS Y 3 LOCALES CON RENTA SOBRE LO...
# ...

# %%
a9 = pickle.load(open("../../../datos/save10.p","rb"))

# %%
a9.head(10)
# Out:
#                                               id  \
# 157310  d28f93e3d85b7dae025380852c8cd283fb7614a4
# 157311  da3459fad3556604e53b51e0b78123ac65ecbd18
# 157312  4f824a7f8fdd2259d4e1a6a8020885d44b00299c
# 157313  61d2bf60d38c65923af5cdbd3c102dc2892cb2bf
# 157314  aa62822b2c267b1d8270b193c961566633575862
# 157315  55af671f421f1466260e13946b7581f3e9414cd1
# 157316  f9626cd2ae80e257aefba8e85e7521404ecc7292
# 157317  3c96e145d51adf43955e224db2bb391832c468b9
# 157319  52e3e0271c7510a4cfc06788566971974872704c
# 157320  993ec394e73aa767a636ba6dbafc8702ebefe943
#
#                                               description  \
# 157310  Departamento semipiso de 1 dormitorio. Ingreso...
# 157311  El emprendimiento tiene unidades entre mediane...
# 157312  14/3/2007: alquiler hasta enero 2018 y no quie...
# 157313  Venta de Casa 4 AMBIENTES en San MatíasBARRIO ...
# 157314  Casa con Cochera subterránea, Córdoba, Córdoba...
# 157315  HDH PRESENTA Oportunidad para inversores! Dupl...
# ...

# %%
a9.tail(10)
# Out:
#                                               id  \
# 162833  e3eab901426523deb4e53a2351f175e46f11fa92
# 162834  5ebbd3616bcdac7005b16823eb11cfd651554113
# 162835  6b57ee5eec2b5e63d16837e370509dcab5c5193c
# 162836  d58da6308699a4ea887cecb6195542d400597caa
# 162840  599a946ea9e84bc1e6297978a430c7db01c576d4
# 162841  65e9f008066b7fb6803b5cf7257deb1643e36c29
# 162842  7673c12cc4d77196964765fa3d26292db559284b
# 162843  a9f0c88bec7fa05c38441082c4991e136c04f873
# 162844  b177cc586217c480724db78981df9e0aa5ca6338
# 162845  e47569fd9fe30cd9bd9a1a6b3c221d94d7f05586
#
#                                               description  \
# 162833  Departamento de 3 ambientes con cochera y baul...
# 162834  Emprendimiento inmobiliario en Palermo Hollywo...
# 162835  Monoambiente a estrenar, frente a vista abiert...
# 162836  En el corazón de Palermo a 20 metros de Avenid...
# 162840  Oportunidad en VENTA de lindìsimo departamento...
# 162841  Impecable Casa en 2 plantas.Planta baja con ja...
# ...

# %%
a10 = pickle.load(open("../../../datos/save11.p","rb"))

# %%
a10.head(10)
# Out:
#                                               id  \
# 162848  a755498b49873066e8c809e4f30472d9b6b3d92f
# 162850  285221c5f504a29fe65e759a23b8fe4c859bdb90
# 162851  f6bbeebf4fa760884299bc40e9b4a1bbb40d1ca7
# 162853  af7d2b3514f0c98e62448370d7e090cf2aae4951
# 162854  99c6fedec1c42f40e06385cc48e118ba42b02f53
# 162856  6e6bd39f333a92922db093fe8ff959a0430b64b2
# 162859  52566884611abc91a0ed71251d20fe5125fe64b2
# 162860  26d7adb8895dbca457eb35404c579889089abfe9
# 162861  fdad21206eb9e2572fc92cfa1c071b8caf2f47e9
# 162862  ddc4ec27703bd1fd750d38fdae736aeb99cbac26
#
#                                               description  \
# 162848  2 PISO, FRENTE. Monoambiente recién alquilado....
# 162850  Casa en venta en La Chacra. Impecable estado, ...
# 162851  Muy buen Chalet en 1 planta a 1 cuadra de Libe...
# 162853  En el corazón de Palermo a 20 metros de Avenid...
# 162854              Es un edificio ubicado en Ituzaing...
# 162856  Emprendimiento inmobiliario en Palermo Hollywo...
# ...

# %%
a10.tail(10)
# Out:
#                                               id  \
# 168718  75c18d4b017e8f6496c2cfed33d0871f3a80494f
# 168719  b931d8b4fb7ee65c0f75281b7dc913bfb0590c9e
# 168720  ff8dd5d7c613659546b90918ff48cc1477b189b9
# 168721  ced944955d0f53ff2599742b3b20681cc3aec626
# 168722  4b0f0e204279b833d03b2476c4e0dc8c2f2dac10
# 168723  ac7593abf77d4b31f15b2c84db1ca2a388ce32a9
# 168724  fc2e0beccf868cd30465687e07c068ba7fc71b3b
# 168725  f4377bd3ad7c429feda92bb51c77084d8fcfbd4e
# 168726  35184ba382229c132cb6d16de067c238381b0784
# 168727  31b8bdcf7ab4c0b511effbb88c94234e7004b580
#
#                                               description  \
# 168718  Excelente propiedad tipo dúplex en Barrio cerr...
# 168719              DESARROLLO INMOBILIARIO EN PRE-POZ...
# 168720  Departamento de 2 ambientes en la zona del nue...
# 168721  Venta lomas del mirador casa sobre lote de 14 ...
# 168722  CODIGO: 2484-FP0389 ubicado en: BELGRANO 2700 ...
# 168723              Winterra S.A.Catamarca 1150CMCPSI5015
# ...

# %%
a11 = pickle.load(open("../../../datos/save12.p","rb"))

# %%
a11.head(10)
# Out:
#                                               id  \
# 168728  77816f8811f96453c3a990de643fcf2d2659ac1b
# 168730  bed12005637a003d531a4dcc3aa5a1076787d3b1
# 168731  fb0007abeb74caed5c693783b617a1d1befa82df
# 168733  877ca74c858bc85dd3373eb265795c7fc3afc1e7
# 168734  ba7121c00740ba13447d21cda96286cead1615b7
# 168735  997b2405ded6af49f75ebe01ff168cfb82291223
# 168736  53162225dcf5fe8202e46f95aad3d6183f8cfe9d
# 168737  31dcf5ef4a9af6f1803aa8b998c9be95b223871f
# 168738  1bcd00c5319313fd70463337fce4d89bb73ebbbc
# 168739  08acdc231bd21c964a16a8af510c4bd444bb3f77
#
#                                               description  \
# 168728  SE TRATA DE UNA VIVIENDA MULTI FAMILIAR CONSIS...
# 168730  Impecable dpto 2 amb. a estrenar con detalles ...
# 168731  Sergio Villella Inmobiliaria presenta departam...
# 168733  LINDO DUPLEX DE 4 AMB: 3 DORM AMPLIOS, 2 BAÑOS...
# 168734  PH AL FRENTE CON ENTRADA INDEPENDIENTE Y ESPAC...
# 168735  Departamento de 2 ambientes a estrenar en comp...
# ...

# %%
a11.tail(10)
# Out:
#                                               id  \
# 187470  b36dec23e370f7fd15521bf11a379d2a874a140f
# 187471  8db5a894e83b44233d77a2894e95e448ea4374d1
# 187472  7e57cce1a2b635205d5571424c7100fa3536f311
# 187473  fab80d207cd3bcf4092627473845f35396670c80
# 187474  38923090847e746add1e7cbdefd03128a2b358da
# 187475  a1de3c3be7e6381dffb267240e123de8c324100b
# 187476  6b119cac3825c981da11b037e41b0014096a3bed
# 187478  aba0d7d6f6f87365d97a4f7bc133f3ef59a70a20
# 187479  e935e6dca58a5b2fec2101f8c7ac1494722119a6
# 187480  d236e3424ac94ab9fcd5d2c22aed59eeed695adc
#
#                                               description  \
# 187470  Vendo O Permuto Depto 3 Amb. C\ Cochera Y C\ 2...
# 187471  Excelentísimo monoambiente al frente. Super lu...
# 187472  Excelente LOFT! Impresionantes medidas.Muy amp...
# 187473  Excelente departamento de 2 ambientes en Paler...
# 187474  CASA EN UNA PLANTA UBICADA EN EL BARRIO CERRAD...
# 187475  ALQUILER DE DEPARTAMENTO 2 AMBIENTES, 40 mts2 ...
# ...

# %%
completo = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11])

# %%
completo.info()

# %%
pickle.dump(completo,open('dataframe.p','wb'))
