# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
import cPickle as pickle
import html5lib
import os
import ipyparallel as ipp

from bs4 import BeautifulSoup as bs
from urllib2 import urlopen
from urllib2 import Request
from urllib2 import URLError

reload(sys)
sys.setdefaultencoding('utf-8')
sys.setrecursionlimit(50000)

# %matplotlib inline

# %% [markdown]
# # Vamos a ir abriendo archivo por archivo y concatenando todos.

# %%
a1 = pickle.load(open("../../../../datos/save1.p","rb"))

# %%
a1.head(10)
# Out:
#                                          id  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2
# 1  a205c53378e7879cf7519659317fb410c060d20e
# 2  9446052c949050359fb08b9f1ba83ba2eaa20c99
# 3  4d3b492ed5f9c74cdf33b56b98328e5c950e3f9c
# 4  61f3789618edabeaa7b5fc06ff36112f8a06557f
# 5  e842ed22eac89b9bffff146377abfd5bceb0b0cd
# 6  4dcfa9a54bdd18cd5438221c6dcfa94738c11c40
# 7  0f0e301809a14b8c069b267fa1c56a3b5ec35d9e
# 8  681ee228d423d9f806d227388bfb7d42e1ac14c9
# 9  fbad0166fa6df0784af5a9210b09ca34ff6e82a1
#
#                                        properati_url  rooms  ambientes  \
# 0  http://www.properati.com.ar/udh_venta_casa_mer...    NaN        NaN
# 1  http://www.properati.com.ar/20hi_venta_casa_me...    3.0        4.0
# 2  http://www.properati.com.ar/4m4m_venta_casa_ma...    5.0        3.0
# 3  http://www.properati.com.ar/518a_venta_departa...    2.0        2.0
# 4  http://www.properati.com.ar/59ec_venta_departa...    2.0        NaN
# ...

# %%
a1.tail(10)
# Out:
#                                             id  \
# 4990  b33efcfeae0ba944929ae56050278834b12b01ab
# 4991  de59747431c9685de8159563a661400987661264
# 4992  6fd30f75b0c0a4e1087a9dd3b65866c0a4138773
# 4993  2b46400cf19f94bfad89b77fed354dba7b7c04e6
# 4994  55a4e98fe760ae8f4d84257762067a6faa1a32e3
# 4995  4eac3869985a42fa45b6354f6e590fa28fb3d0ec
# 4996  62646eb4e351d40e486aba099ebef8979bf6a317
# 4997  c757edc5735b842e24a7ca25b7a7171256c64f3f
# 4998  43dd0937a5aaa6167f4271d2db91340b9df9c4ef
# 4999  d98c8f78543082c7744d405b77b9a0953c80da2c
#
#                                           properati_url  rooms  ambientes  \
# 4990  http://www.properati.com.ar/od2g_venta_departa...    1.0        2.0
# 4991  http://www.properati.com.ar/od2h_venta_departa...    3.0        3.0
# 4992  http://www.properati.com.ar/od2n_venta_departa...    3.0        NaN
# 4993  http://www.properati.com.ar/od2o_venta_departa...    4.0        2.0
# ...

# %%
a2 = pickle.load(open("../../../../datos/save2.p","rb"))

# %%
a2.head(10)
# Out:
#                                             id  \
# 5000  bb21256084e278a2f39ddbc1865303a063ff4cef
# 5001  7974b5eed851fc1f3e728e03b1927a5105584386
# 5002  ac1b4a969cd7dc0dd6e06ff88123842ef17f57c4
# 5003  53f6449c98fa7964f18618cb45a0b4582f39d0a2
# 5004  2a786dbaab3b03ef9045aafa0b79d3288e18c79b
# 5005  56869c81ab7f0c60c68832d75a94415db41360f9
# 5006  4218536bca46ea3ac8d0bf9c3dd6944b1b0380f9
# 5007  9890fc29075ee20945225d47b98fe47029aa91e1
# 5008  e56b68aaeebd0a6c46925bcba021076fcddebfc1
# 5009  3deac9b339c9d67350f54f25e05fa59a47adc73d
#
#                                           properati_url  rooms  ambientes  \
# 5000  http://www.properati.com.ar/od4n_venta_departa...    3.0        3.0
# 5001  http://www.properati.com.ar/od4q_venta_ph_vill...    3.0        3.0
# 5002  http://www.properati.com.ar/od4r_venta_departa...    4.0        NaN
# 5003  http://www.properati.com.ar/od4t_venta_ph_vill...    2.0        2.0
# ...

# %%
a2.tail(10)
# Out:
#                                             id  \
# 9990  2a97e2ae894819665c22df2146bebe7574abdcf4
# 9991  c58a9d880055efbd47415a439be88edc85c914ae
# 9992  40abc0bd78e0d38278b1aa030e4e619ddc729286
# 9993  f3a0f6119077aa57365e544c753ccedfcd9afcd4
# 9994  977f099074918587ba67d95307290ca3060eed01
# 9995  88b9a4b02f8f204556ef4819f32fd1752b3e9034
# 9996  eb03cbde64a3dd7eba346ffa4c8fe6fe1b8f4a4d
# 9997  1d7efa7d24ed70d9438b72152a982c5257f3c03d
# 9998  07dfb82aae6905ac8f33f66b9d5618a4129f3fc8
# 9999  a5c444529a73fc9ce6a5ca04a7d95289bd7abb66
#
#                                           properati_url  rooms  ambientes  \
# 9990  http://www.properati.com.ar/w2sh_venta_casa_be...    3.0        NaN
# 9991  http://www.properati.com.ar/w2so_venta_departa...    1.0        3.0
# 9992  http://www.properati.com.ar/w2sz_venta_departa...    NaN        2.0
# 9993  http://www.properati.com.ar/w2t0_venta_departa...    NaN        2.0
# ...

# %%
a3 = pickle.load(open("../../../../datos/save3.p","rb"))

# %%
a3.head(10)
# Out:
#                                              id  \
# 10000  937678bddf454999bc50cd620a0fbb4535334285
# 10001  1ca8aaa505fe92ef3d5f8ae771cb82d40bb6151d
# 10002  c6c85456a09066aaaa223dfa0a52d69b631e8502
# 10003  90a6857ee4a9f6175260596a31e68c81d5637679
# 10004  2f967d3c1b39919de7a8b9fab863b89d5c370269
# 10005  56d7054198c6c520799c0a8de8098929950f713b
# 10006  e3d8e45372213fe2dc4f27534e24427ea07ee990
# 10007  09388e10e31578c8919a98e83ab0a577b7c40e34
# 10008  1b21ac98c745b8167499723dc67490ec5c9a27ec
# 10009  bd909275730671ac34da584bac82aa3444fa8d42
#
#                                            properati_url  rooms  ambientes  \
# 10000  http://www.properati.com.ar/w2uy_venta_departa...    2.0        2.0
# 10001  http://www.properati.com.ar/w2uz_venta_departa...    2.0        2.0
# 10002  http://www.properati.com.ar/w2v0_venta_departa...    2.0        2.0
# 10003  http://www.properati.com.ar/w2v1_venta_departa...    2.0        2.0
# ...

# %%
a3.tail(10)
# Out:
#                                              id  \
# 14990  fec0c39719f78eeee148b1f89cd356a2a5190680
# 14991  96aef671675ca3229c2766d57122ce4d949f1c7d
# 14992  533a935ce43f3a48bd3fbc7bec179a61cd324fc3
# 14993  02984c48c9ab0113892036cc7cb749a057d00b76
# 14994  127cac4bbac33bb3c877dd3da7db7770db5d5e73
# 14995  20aa655e3fe3a2170c79ee1b1712d0e1a9dcce2e
# 14996  ceff7412943cb175e14911339348b5b0f634aa21
# 14997  618fe2134b71866f5f440c00ba7c9f7d8d0dafe5
# 14998  63341d4ff20a9e8b228b4f9e2a128893c3193f11
# 14999  eb3d4c2199bb9e25e2c3459c50916e3113f1773c
#
#                                            properati_url  rooms  ambientes  \
# 14990  http://www.properati.com.ar/zq9y_venta_casa_be...    3.0        NaN
# 14991  http://www.properati.com.ar/zqag_venta_departa...    3.0        NaN
# 14992  http://www.properati.com.ar/zqaq_venta_departa...    NaN        3.0
# 14993  http://www.properati.com.ar/zqay_venta_casa_bs...    5.0        NaN
# ...

# %%
a4 = pickle.load(open("../../../../datos/save4.p","rb"))

# %%
a4.head(10)
# Out:
#                                              id  \
# 15000  6245128edd0eb6f7d49f49932d9875e93d93b125
# 15001  226094e8d4ed7926ffca012d3971c9d22af2391a
# 15002  3860d26a7d2896e44fd711c190d608802ac2d57e
# 15003  d8a8a7fb50d6f4e83ece2c66b2d2f7a5b1da0106
# 15004  79b8d5f462c62728fc9305cc9129d8dc1d759824
# 15005  006d1f92f68f69b59aece28cd1410b58a62c795c
# 15006  019ebf8619b9c1d1fec61cb6cf2dec986e4ef29f
# 15007  5d93f71d0923e917868f94f0b02d65c0b11e298e
# 15008  81b1b237a6639eca19bfbc96d379d99a8b8e37ba
# 15009  f87bc9f7c7f551a31e529d2888c5f0c74aa0cbf3
#
#                                            properati_url  rooms  ambientes  \
# 15000  http://www.properati.com.ar/zqck_venta_casa_ca...    3.0        4.0
# 15001  http://www.properati.com.ar/zqcm_venta_departa...    3.0        4.0
# 15002  http://www.properati.com.ar/zqd7_venta_casa_mu...    2.0        2.0
# 15003  http://www.properati.com.ar/zqn1_venta_departa...    5.0        NaN
# ...

# %%
a4.tail(10)
# Out:
#                                              id  \
# 19990  0216b39519bd9d46ee5fa0ebbacc2830d1dff895
# 19991  bdc55b6b25a45751f1020ee13468a54f9f309af6
# 19992  e5cc5e1c82f842a7685c9c3e4ce5f1e9aecd40b7
# 19993  aefc6409c86c1aade4b8694220e0d6935f860804
# 19994  11b05373bbab1153d2c08a46c86c8d86be1a6710
# 19995  9c1b439d6c3c7ad2c95f3ae2fabe88959baa828b
# 19996  394ee89eb4cb5236a00e4ee83567954aa15e28cc
# 19997  803ca15aac89a25279d22bf2bb7761e0964ef8f5
# 19998  491317686959e67ac910cf296adb7d1c6c5e9934
# 19999  b72d457c80053fdc0f0dfa960f77d515e9f61b6e
#
#                                            properati_url  rooms  ambientes  \
# 19990  http://www.properati.com.ar/11wn3_venta_casa_m...    3.0        NaN
# 19991  http://www.properati.com.ar/11wn5_venta_casa_m...    2.0        NaN
# 19992  http://www.properati.com.ar/11wnb_venta_casa_m...    4.0        NaN
# 19993  http://www.properati.com.ar/11wnh_venta_casa_m...    7.0        NaN
# ...

# %%
a5 = pickle.load(open("../../../../datos/save5.p","rb"))

# %%
a5.head(10)
# Out:
#                                              id  \
# 20000  9fcab711ad151b9d2de661988ae93247650c5602
# 20001  e31ab617da295a6532463b95ba9aacf50da69020
# 20002  9831de82a9967f9d8b4330598def0a1daf0beadf
# 20003  4acbec7aaf93872df6e468bff708e1747e1b6074
# 20004  b8e987d930cc13f068698883c0a253241bcb433a
# 20005  91a84fd045cc6b1328a2314f73b116ef9bddd083
# 20006  c38c2b556331136a93e03ef92a347036f9105666
# 20007  f2f6e89f31a92ad22070ca7e120469a1a714e7e2
# 20008  294a19e251aec6b13c0f323eff3f33af1e314aac
# 20009  f1be98235db3cd9d37f4b96129896b7347937c80
#
#                                            properati_url  rooms  ambientes  \
# 20000  http://www.properati.com.ar/11wpf_venta_casa_s...    3.0        NaN
# 20001  http://www.properati.com.ar/11wrr_venta_ph_mat...    2.0        NaN
# 20002  http://www.properati.com.ar/11wrs_venta_ph_vil...    2.0        NaN
# 20003  http://www.properati.com.ar/11ws2_venta_depart...    NaN        NaN
# ...

# %%
a5.tail(10)
# Out:
#                                              id  \
# 24990  f4084dddd2995826e7c73f4c38ec7e40dba5cdc4
# 24991  faac5e04a5e043fc1ec98d2a731d806fe42b5ef3
# 24992  4786d88bd9c2a3812db16dfd2c82ccb918123350
# 24993  45403b5055ebe837cadbd950e798cbee08e2bda5
# 24994  0e838e54633c0cd29120ca2263fb9c1ce34b5d6d
# 24995  9626a0b71eb25b0813f14cc7986fa3bd72166c8e
# 24996  f6425408649cd816a57d3cd48198e32130178d92
# 24997  bbe6289e6f1b8f534f2642d4a60d037b56c50597
# 24998  1e11552cd6ae9cf39741c3450a14dea8be9cf5c1
# 24999  863d07402e34a707e88273e36ca24494e38892ed
#
#                                            properati_url  rooms  ambientes  \
# 24990  http://www.properati.com.ar/13q6j_venta_casa_v...    5.0        5.0
# 24991  http://www.properati.com.ar/13q7j_venta_depart...    2.0        2.0
# 24992  http://www.properati.com.ar/13q7k_venta_depart...    2.0        2.0
# 24993  http://www.properati.com.ar/13q7l_venta_depart...    2.0        2.0
# ...

# %%
a6 = pickle.load(open("../../../../datos/save6.p","rb"))

# %%
a6.head(10)
# Out:
#                                              id  \
# 25000  f6dd75050ba6eb1b237023074af59f8a531744b8
# 25001  5819a0bb18fffbefd24b4dbb53777df75344d6da
# 25002  135b9cb7dc80f2358f9d9cf5dc86278a8909e46e
# 25003  da5db4fbe0c959f7c4fca26930c1cdcc6fecb112
# 25004  c70fa4aba5b23ccce1b8cac47763362f44039153
# 25005  270fe11f279c1da830653303a5fb8b58c0aa2420
# 25006  a12c6ae91dedf253b1034cdd806702fe58c75081
# 25007  a46c03c2c4468249ac6507c012e5cca22d05f58e
# 25008  e942868a8948d9906b8b3b1da5fc94b1c1f7c442
# 25009  f18eb8bc20f9ab0a5dd5b3509fd9c366bc2d12b2
#
#                                            properati_url  rooms  ambientes  \
# 25000  http://www.properati.com.ar/13q7s_venta_depart...    1.0        1.0
# 25001  http://www.properati.com.ar/13q7t_venta_local_...    NaN        NaN
# 25002  http://www.properati.com.ar/13q86_venta_ph_col...    4.0        4.0
# 25003  http://www.properati.com.ar/13q88_venta_ph_col...    3.0        3.0
# ...

# %%
a6.tail(11)
# Out:
#                                              id  \
# 29989  663552ad62f1fc7bf936e7f276d3f94d1a956f9d
# 29990  0cc3a08589f6e6de1721dd0ad0090d7b6b12b5a6
# 29991  83e6bac8a58a406474dcf9c34491e9bad48ea3a6
# 29992  a84284931867a25277790dd7efe9c9053e757f21
# 29993  924c0ff90abfc81f8bd03371910d2367cbb8385a
# 29994  89be9e729d60d721e690ea32d7b698f0706c0040
# 29995  e39d319350041a6e96ab112c41bdb28ec2a858ce
# 29996  7ad7197f057138cc3d2742ad102923c2a50cc484
# 29997  e11181d4188ef2a9995b951559307d29f1d23789
# 29998  ece5bca846235d258a338d9d227671a120d4265b
# 29999  0607c2d359002873e34760c7e4dd1aa82b9309f3
#
#                                            properati_url  rooms  ambientes  \
# 29989  http://www.properati.com.ar/14zbg_venta_casa_s...    5.0        6.0
# 29990  http://www.properati.com.ar/14zbh_venta_casa_f...    NaN        3.0
# 29991  http://www.properati.com.ar/14zbs_venta_ph_san...    NaN        2.0
# 29992  http://www.properati.com.ar/14zc1_venta_casa_f...    NaN        NaN
# ...

# %%
a7 = pickle.load(open("../../../../datos/save7.p","rb"))

# %%
a7.head(10)
# Out:
#                                              id  \
# 30000  8df6bd520616fb6d904d57f54702b32a9278815a
# 30001  1cba92a717f0a2a6c8f270d9e522099e9f35f7ad
# 30002  3c0f02a3dd020cf705b6c954bcd68f5562eeab42
# 30003  2456b35fa5d840f86c97b50393d59a38253d4d93
# 30004  9f959126e46db5c8c09962491542ec61dc92a32b
# 30005  cf3ec4aa663dcf7e0d485754c2d0ee97abccef66
# 30006  56983aafb864f6f1409e6a5236f8309f7bf58889
# 30007  aee6ecdd81d13b1fbaea0ddb6fcecb1647b1959a
# 30008  825d00bdd07c00b82773fed6ccb43e63df12642f
# 30009  62396705162690194da2ddd4d701cfac0b5bb509
#
#                                            properati_url  rooms  ambientes  \
# 30000  http://www.properati.com.ar/14zcr_venta_depart...    NaN        1.0
# 30001  http://www.properati.com.ar/14zcs_venta_depart...    NaN        NaN
# 30002  http://www.properati.com.ar/14zd6_venta_depart...    NaN        2.0
# 30003  http://www.properati.com.ar/14zd7_venta_depart...    NaN        1.0
# ...

# %%
a7.tail(10)
# Out:
#                                              id  \
# 34990  af43d7c141d2923d97f2e0eccb421a45596457f5
# 34991  87f1bfb31ca7a003edd9efc5f9e9aa177655742e
# 34992  55e5f78e4f2c0f87977e01214bf54b36565ee3df
# 34993  0daca0c2327967630a4d2e46aa911780d8aa5cb5
# 34994  84f59688db1e43304d9c972461a55fb4eeea77ff
# 34995  fe8d8a6c1d232decf905de25081b8a6e5178dc0a
# 34996  be97aaede4662925ac10242705f9ddce04d8479a
# 34997  b304d83b20f9df3426f789467ac2406f308c3228
# 34998  d8078757d47a52c209fe4e4bb3eee260e6ed31c4
# 34999  63967e9f80f856773d3ab7ebd4d159c1aa5108d1
#
#                                            properati_url  rooms  ambientes  \
# 34990  http://www.properati.com.ar/160xd_venta_depart...    1.0        1.0
# 34991  http://www.properati.com.ar/160xg_venta_depart...    2.0        NaN
# 34992  http://www.properati.com.ar/160xj_venta_depart...    1.0        NaN
# 34993  http://www.properati.com.ar/160xm_venta_depart...    4.0        NaN
# ...

# %%
a8 = pickle.load(open("../../../../datos/save8.p","rb"))

# %%
a8.head(10)
# Out:
#                                              id  \
# 35000  2d6d8636016ab0e3312494df31f432410aedffdf
# 35001  8aa0ef67446e526f17821a617608f7f4c79d69d8
# 35002  be19d25af171df95c023db578a248cdd2b116a8b
# 35003  a9861da7a1b8e9601fba9b80d842589265a4afb1
# 35004  5cc90cd548d70a604baed17aecd87b35c26cb301
# 35005  41d14d7f92404171d11be8345bdb51b04ca4f587
# 35006  5dce2ece080ef62d9da752e37f182cb9f30617d7
# 35007  5d921d0ffca05fa14db920648f8cfcf89cab8c01
# 35008  ceb4ae4790b337cd1d597cad5ecccb5e1da2c084
# 35009  00f8076b545e9fcd914926c4c250e5627f909e8d
#
#                                            properati_url  rooms  ambientes  \
# 35000  http://www.properati.com.ar/160y2_venta_depart...    5.0        5.0
# 35001  http://www.properati.com.ar/160y5_venta_casa_p...    3.0        9.0
# 35002  http://www.properati.com.ar/160y7_venta_casa_n...    3.0        NaN
# 35003  http://www.properati.com.ar/160y8_venta_depart...    3.0        3.0
# ...

# %%
a8.tail(10)
# Out:
#                                              id  \
# 39990  c538cef628af3743eb1dd26d90972a5c48315b14
# 39991  f75bb634193d7eb6e51f01fddb36328a79420fda
# 39992  ea1c3209276f2970367f24e768568f6d7090c35d
# 39993  dfc8d2a2153870b4b3e5fc0a849d9f9611fb9474
# 39994  0cc856a0a689b68c7759b26e9c3a7fb441acb581
# 39995  3c5b48b6703f533a4d958a93241b26c9e2fa4d9b
# 39996  dbf03c9a7090e24233ceed35d5351686acac67db
# 39997  1ad9f3a29d3a9d13c89f8a7909e84a31ba338436
# 39998  db8af7c8b1b2624e68ffe54b99bff9faa77622f6
# 39999  1f78ad9f9937ef8c69b8c22a926d7c5fe1134e10
#
#                                            properati_url  rooms  ambientes  \
# 39990  http://www.properati.com.ar/174s5_venta_casa_b...    5.0        NaN
# 39991  http://www.properati.com.ar/174s6_venta_depart...    4.0        4.0
# 39992  http://www.properati.com.ar/174sc_alquiler_loc...    NaN        NaN
# 39993  http://www.properati.com.ar/174sf_venta_depart...    2.0        2.0
# ...

# %%
a9 = pickle.load(open("../../../../datos/save9.p","rb"))

# %%
a9.head(10)
# Out:
#                                              id  \
# 40000  8a8dba26cfd807402958771988b6fe3e7fe4fa12
# 40001  13967b4386f3f11ef0b93df26fac74c29e6c848e
# 40002  0288c3a8e9f7d229a06bde4c9a4e1c63aef3abd0
# 40003  78015795293cfdd35c1f197dade9f4df50ffe18d
# 40004  ef6bd0b2eba135f3f58e2bfe74e5acb9168aa605
# 40005  c990b43462e8368197c76dccf5c6f69001b89b01
# 40006  ebe62d39e3b92879a54f64f30c43f378caa347d3
# 40007  dbc70a8406fa11acc6bef17013914af3c61c2ee7
# 40008  015bf19c746a9cfaae2d6cb14d8beeaf3d3857c3
# 40009  40794b305ad02cb74719025baf3c095d75b60015
#
#                                            properati_url  rooms  ambientes  \
# 40000  http://www.properati.com.ar/174st_venta_depart...    5.0        5.0
# 40001  http://www.properati.com.ar/174sw_venta_depart...    5.0        5.0
# 40002  http://www.properati.com.ar/174sx_venta_depart...    1.0        1.0
# 40003  http://www.properati.com.ar/174sy_venta_depart...    1.0        1.0
# ...

# %%
a9.tail(10)
# Out:
#                                              id  \
# 44990  2f4e690a2d4b0de2ba2dd2eca8733550e72b5545
# 44991  26a76e8ad914742d2617456c53bb201ccdeed68c
# 44992  bce1cd6af1f0b0d125b8852fb89bec0d1f1445de
# 44993  713dbf65e2f576b0138df34f78ae55f77ba0c812
# 44994  9503987a8e4bcde1a5df8e0eb114cb6f263395c3
# 44995  2d73868c88fef9b4743f4d495b342275fee97ccd
# 44996  af9a0af4297279953efc34c22303c815a1f62ea8
# 44997  ccb48acb5eed8a1360af98369d148ddf7e69c3a6
# 44998  52fcea7a0e028671a3c1904f6ca1cbc0626462ef
# 44999  4f082fa205dbd96291acafc6f3ccaa282a986896
#
#                                            properati_url  rooms  ambientes  \
# 44990  http://www.properati.com.ar/17qvc_venta_depart...    1.0        1.0
# 44991  http://www.properati.com.ar/17qvd_venta_casa_g...    2.0        2.0
# 44992  http://www.properati.com.ar/17qve_venta_depart...    3.0        NaN
# 44993  http://www.properati.com.ar/17qvf_venta_ph_gen...    3.0        NaN
# ...

# %%
a10 = pickle.load(open("../../../../datos/save10.p","rb"))

# %%
a10.head(10)
# Out:
#                                              id  \
# 45000  a560f2dc329c7172f36e44c8e5d8cadaa1caa525
# 45001  e3c3c7c925986e735b05344ec609c4fc3e270e95
# 45002  f6f50fa808829cc233f0381d87045217d87b5a88
# 45003  36f7cfce6955e9d98cb66456a81e0fc445c0aa12
# 45004  476fe3e957b828f5fd6ed7ff847b91570e3e0a03
# 45005  eb818bbe795292a456a02ce8fbf68bad2eddb52a
# 45006  e5c54e3a48503c59118cacca5da1a8f6aeb3756f
# 45007  cc7576dd3f29f30458df091144b58cdacb47c4d4
# 45008  ceada0caadb664f5354941730c8bfd7413976cb2
# 45009  1a6cf358b7127c5846f012d413678a92a56dda5c
#
#                                            properati_url  rooms  ambientes  \
# 45000  http://www.properati.com.ar/17qvo_venta_casa_g...    4.0        3.0
# 45001  http://www.properati.com.ar/17qvp_venta_depart...    3.0        3.0
# 45002  http://www.properati.com.ar/17qvq_venta_depart...    1.0        2.0
# 45003  http://www.properati.com.ar/17qvs_venta_depart...    3.0        NaN
# ...

# %%
a10.tail(10)
# Out:
#                                              id  \
# 49990  2db0482f8f00a4518835521e50da5223628831e8
# 49991  f59299ec9a6c04346140828c3b913f5295b64437
# 49992  f635b1e24982c5c29552d8207a6f7d7c0a3afdf3
# 49993  eb2f12095de43d05f8a5b3f9b02b844bb1b4993f
# 49994  62116b91d52759c7894989f45c68b6c2bbcb742c
# 49995  9f946384797b178e921a05ce82667fd494caff2c
# 49996  2db95ba294e4b5e63a6c2e7747c4e107316ef0f9
# 49997  7a732c9c9da141b559f524a3404d949cca62d1bb
# 49998  9fe74028e0c38784481b884946f7037b4b420e98
# 49999  7e761cc804929634e4011cb8090aca1c593567bd
#
#                                            properati_url  rooms  ambientes  \
# 49990  http://www.properati.com.ar/18cdy_venta_casa_g...    NaN        4.0
# 49991  http://www.properati.com.ar/18ce2_venta_casa_m...    NaN        NaN
# 49992  http://www.properati.com.ar/18ce4_venta_casa_c...    4.0        NaN
# 49993  http://www.properati.com.ar/18ce7_venta_casa_s...    3.0        NaN
# ...

# %%
completo = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10])

# %%
completo.info()

# %%
pickle.dump(completo,open('dataframe1.p','wb'))
