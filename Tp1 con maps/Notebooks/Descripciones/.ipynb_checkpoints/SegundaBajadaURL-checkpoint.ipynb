# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
import cPickle as pickle
import html5lib
import os
import ipyparallel as ipp

from bs4 import BeautifulSoup as bs
from urllib2 import urlopen
from urllib2 import Request
from urllib2 import URLError

reload(sys)
sys.setdefaultencoding('utf-8')
sys.setrecursionlimit(50000)

# %matplotlib inline

# %%
#Corremos el cluster
rc = ipp.Client()
ar = rc[:].apply_async(os.getpid)
pid_map = ar.get_dict()

# %% [markdown]
# # Cargamos los datos de las propiedades

# %%
data = pickle.load(open("../../../datos/DataFrame.p","rb"))

# %% [markdown]
# # Vamos a hacer un analisis para ver que criterio tomo para bajar un par de datos mas

# %%
data.info()

"""
rooms               61200
ambientes           49081
banios              13639
webp                20196
"""

# %% [markdown]
# Los que menos tienen son ambientes y banios, voy a ver cuantos features no tienen ninguno de los 2

# %%
parc = data[pd.isnull(data['ambientes']) == True]
parc = parc[pd.isnull(parc['banios']) == True]
parc = parc[pd.isnull(parc['webp']) == True]

# %%
parc.info() #Tenemos 23000 masomenos

# %% [markdown]
# Pruebo ahora con los que no tienen banios ni cuartos

# %%
parc1 = data[pd.isnull(data['rooms']) == True]
parc1 = parc1[pd.isnull(parc1['banios']) == True]
parc1 = parc1[pd.isnull(parc1['webp']) == True]

# %%
parc1.info()

# %% [markdown]
# # Voy a bajar los que no tienen ni ambientes ni banios

# %%
data.head(5)
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 2  9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
# 3  4d3b492ed5f9c74cdf33b56b98328e5c950e3f9c  2013-01-04      sell
# 4  61f3789618edabeaa7b5fc06ff36112f8a06557f  2013-01-26      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
# 2         house             Mataderos
# 3     apartment                 Pilar
# 4     apartment                 Pilar
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 4         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
#
#                  state_name  geonames_id                        lat-lon  \
# 0  Bs.As. G.B.A. Zona Oeste    3429244.0                            NaN
# 1  Bs.As. G.B.A. Zona Oeste    3429244.0                            NaN
# 2           Capital Federal    3430787.0  -34.6544492346,-58.4895603251
# 3  Bs.As. G.B.A. Zona Norte    3429979.0          -34.429071,-58.795418
# 4  Bs.As. G.B.A. Zona Norte    3429979.0          -34.439241,-58.798589
#
#                          ...                          expenses  \
# 0                        ...                               NaN
# 1                        ...                               NaN
# 2                        ...                               NaN
# 3                        ...                               NaN
# 4                        ...                               NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/udh_venta_casa_mer...
# 1  http://www.properati.com.ar/20hi_venta_casa_me...
# 2  http://www.properati.com.ar/4m4m_venta_casa_ma...
# 3  http://www.properati.com.ar/518a_venta_departa...
# 4  http://www.properati.com.ar/59ec_venta_departa...
#
#                                          description  \
# 0  CASA CON LOCAL EN VENTA EN PADUA.2 DORMITORIOS...
# 1  CHALET VENTA 4 AMBIENTES PADUA.EXCELENTE CHALE...
# 2  Casa Multifamiliar en Mataderos!!! Sobre lote ...
# 3  Venta - Departamento - Argentina, Buenos Aires...
# 4  Venta - Departamento - Argentina, Buenos Aires...
#
#                                              title  \
# 0                                    CASA EN VENTA
# 1                                    CASA EN VENTA
# 2                                    CASA EN VENTA
# 3  Departamento en Venta ubicado en Arcos de Pilar
# 4           Departamento en Venta ubicado en Pilar
#
#                                      image_thumbnail  \
# 0  https://thumbs4.properati.com/1/ufoyqwscVk8n3e...
# 1  https://thumbs4.properati.com/5/I5RS_jAIUseo9H...
# 2  https://thumbs4.properati.com/6/DsNJjCb5_zIPV0...
# 3  https://thumbs4.properati.com/8/bJn9FqcBRGi_8H...
# 4  https://thumbs4.properati.com/5/hiXoFGFHBiIhV2...
#
#                              latlon  rooms  ambientes  banios  \
# 0            (-34.66692, -58.70097)    NaN        NaN     2.0
# 1            (-34.66692, -58.70097)    3.0        4.0     NaN
# 2  (-34.6544492346, -58.4895603251)    5.0        3.0     NaN
# 3          (-34.429071, -58.795418)    2.0        2.0     NaN
# 4          (-34.439241, -58.798589)    2.0        NaN     NaN
#
#                                                 webp
# 0  <!DOCTYPE html>\n<!--[if lt IE 7 ]> <html clas...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
# [5 rows x 31 columns]

# %%
data = data[0:]

# %%
def chequearCuartos(x):
    if(not pd.isnull(x[4])):
        return x[4]
    return buscarCuartos(x[1]) or buscarCuartos(x[2])
        
def buscarCuartos(x):
    
    caract = ""
    caractViviendas = ['dorm','hab','cuarto'] 
    
    if( x == None or x == ""):
        return None
    
    if type( x ) is str:
        x = x.lower()
    if type( x ) is float:
        x = str(x).lower()
    #Queda una lista separada por comas.    
    x = x.split()
    
    for j in xrange(len(caractViviendas)):
        
        aux = ""
        palabraAct = caractViviendas[j]
        
        if( palabraAct in x ):
            indice = x.index( palabraAct )
            #caract = buscarCantidadDorm(x,indice)
            caract = x[indice-1]
            break;
            
        else:
            for ind in xrange( len(x) ):
                if( palabraAct in x[ind] ):
                    #caract = buscarCantidadDorm(x,ind)
                    caract = x[ind-1]
                    break;
    if(caract.isdigit()):
        return int(caract)
    return None

# %%
caracteristicas['rooms'] = caracteristicas.apply(chequearCuartos, axis=1)

# %%
#caracteristicas['rooms'].isnull().sum()#62257
# Out:
# 1

# %%
caracteristicas.head(10)
# Out:
#                                               id  \
# 168728  77816f8811f96453c3a990de643fcf2d2659ac1b
# 168730  bed12005637a003d531a4dcc3aa5a1076787d3b1
# 168731  fb0007abeb74caed5c693783b617a1d1befa82df
# 168733  877ca74c858bc85dd3373eb265795c7fc3afc1e7
# 168734  ba7121c00740ba13447d21cda96286cead1615b7
# 168735  997b2405ded6af49f75ebe01ff168cfb82291223
# 168736  53162225dcf5fe8202e46f95aad3d6183f8cfe9d
# 168737  31dcf5ef4a9af6f1803aa8b998c9be95b223871f
# 168738  1bcd00c5319313fd70463337fce4d89bb73ebbbc
# 168739  08acdc231bd21c964a16a8af510c4bd444bb3f77
#
#                                               description  \
# 168728  SE TRATA DE UNA VIVIENDA MULTI FAMILIAR CONSIS...
# 168730  Impecable dpto 2 amb. a estrenar con detalles ...
# 168731  Sergio Villella Inmobiliaria presenta departam...
# 168733  LINDO DUPLEX DE 4 AMB: 3 DORM AMPLIOS, 2 BAÑOS...
# 168734  PH AL FRENTE CON ENTRADA INDEPENDIENTE Y ESPAC...
# 168735  Departamento de 2 ambientes a estrenar en comp...
# 168736  IMPORTANTE PROPIEDAD DESARROLLADA EN SOLO UNA ...
# 168737  Lindísimo departamento a Estrenar:   está ubic...
# 168738              Winterra S.A.Catamarca 1150CMCPSI5015
# 168739  Casa de 1 dormitorio, cocina comedor y baño. T...
#
#                                                     title  \
# 168728                                       Casa - Merlo
# 168730                        Departamento - San Fernando
# 168731   Ov. Lagos 600 - Venta departamento monoambiente.
# 168733                     Casa en Florida Belgrano-Oeste
# 168734                     PH 3 AMB. APTO CRÉDITO - Moron
# 168735        Departamento - Condominios Intercontinental
# 168736                                    Casa - La Plata
# 168737  BELLISIMO 2 AMBIENTES CON GRAN TERRAZA Y COCHERA.
# 168738           Departamento Lagoon Pilar Sector Serena!
# 168739                                   Casa - El Bolson
#
#                                             properati_url  rooms
# 168728  http://www.properati.com.ar/1bqtk_venta_casa_m...    NaN
# 168730  http://www.properati.com.ar/1bqto_venta_depart...    NaN
# 168731  http://www.properati.com.ar/1bqtq_venta_depart...    NaN
# 168733  http://www.properati.com.ar/1bqts_venta_casa_f...    3.0
# 168734  http://www.properati.com.ar/1bqtt_venta_ph_mor...    4.0
# 168735  http://www.properati.com.ar/1bqtu_venta_depart...    NaN
# 168736  http://www.properati.com.ar/1bqtv_venta_casa_l...    NaN
# 168737  http://www.properati.com.ar/1bqtx_venta_depart...    NaN
# 168738  http://www.properati.com.ar/1bqty_venta_depart...    NaN
# 168739  http://www.properati.com.ar/1bqu0_venta_casa_s...    1.0

# %% [markdown]
# # Ahora añadimos los ambientes

# %%
caracteristicas['ambientes'] = pd.Series(None, index=caracteristicas.index)

# %%
def chequearAmbientes(x):
    
    if(not pd.isnull(x[5])):
        return x[5]
    return buscarAmbientes(x[1]) or buscarAmbientes(x[2])
        
def buscarAmbientes(x):
    
    caract = ""
    caractViviendas = ['amb','monoamb'] 
    
    if( x == None or x == ""):
        return None
    
    if type( x ) is str:
        x = x.lower()
    if type( x ) is float:
        x = str(x).lower()
    #Queda una lista separada por comas.    
    x = x.split()
    
    for j in xrange(len(caractViviendas)):
        
        aux = ""
        palabraAct = caractViviendas[j]
        
        if( palabraAct in x ):
            indice = x.index( palabraAct )
            if(palabraAct == 'monoamb'):caract = '1'
            else: caract = x[indice-1]
            break;
            
        else:
            for ind in xrange( len(x) ):
                if( palabraAct in x[ind] ):
                    if(palabraAct == 'monoamb'):caract = '1'
                    else: caract = x[ind-1]
                    break;
    
    if(caract.isdigit()):
        return int(caract)
    return None

# %%
caracteristicas['ambientes'] = caracteristicas.apply(chequearAmbientes, axis=1)

# %%
caracteristicas.head(10)
# Out:
#                                               id  \
# 168728  77816f8811f96453c3a990de643fcf2d2659ac1b
# 168730  bed12005637a003d531a4dcc3aa5a1076787d3b1
# 168731  fb0007abeb74caed5c693783b617a1d1befa82df
# 168733  877ca74c858bc85dd3373eb265795c7fc3afc1e7
# 168734  ba7121c00740ba13447d21cda96286cead1615b7
# 168735  997b2405ded6af49f75ebe01ff168cfb82291223
# 168736  53162225dcf5fe8202e46f95aad3d6183f8cfe9d
# 168737  31dcf5ef4a9af6f1803aa8b998c9be95b223871f
# 168738  1bcd00c5319313fd70463337fce4d89bb73ebbbc
# 168739  08acdc231bd21c964a16a8af510c4bd444bb3f77
#
#                                               description  \
# 168728  SE TRATA DE UNA VIVIENDA MULTI FAMILIAR CONSIS...
# 168730  Impecable dpto 2 amb. a estrenar con detalles ...
# 168731  Sergio Villella Inmobiliaria presenta departam...
# 168733  LINDO DUPLEX DE 4 AMB: 3 DORM AMPLIOS, 2 BAÑOS...
# 168734  PH AL FRENTE CON ENTRADA INDEPENDIENTE Y ESPAC...
# 168735  Departamento de 2 ambientes a estrenar en comp...
# 168736  IMPORTANTE PROPIEDAD DESARROLLADA EN SOLO UNA ...
# 168737  Lindísimo departamento a Estrenar:   está ubic...
# 168738              Winterra S.A.Catamarca 1150CMCPSI5015
# 168739  Casa de 1 dormitorio, cocina comedor y baño. T...
#
#                                                     title  \
# 168728                                       Casa - Merlo
# 168730                        Departamento - San Fernando
# 168731   Ov. Lagos 600 - Venta departamento monoambiente.
# 168733                     Casa en Florida Belgrano-Oeste
# 168734                     PH 3 AMB. APTO CRÉDITO - Moron
# 168735        Departamento - Condominios Intercontinental
# 168736                                    Casa - La Plata
# 168737  BELLISIMO 2 AMBIENTES CON GRAN TERRAZA Y COCHERA.
# 168738           Departamento Lagoon Pilar Sector Serena!
# 168739                                   Casa - El Bolson
#
#                                             properati_url  rooms  ambientes
# 168728  http://www.properati.com.ar/1bqtk_venta_casa_m...    NaN        NaN
# 168730  http://www.properati.com.ar/1bqto_venta_depart...    NaN        2.0
# 168731  http://www.properati.com.ar/1bqtq_venta_depart...    NaN        1.0
# 168733  http://www.properati.com.ar/1bqts_venta_casa_f...    3.0        4.0
# 168734  http://www.properati.com.ar/1bqtt_venta_ph_mor...    4.0        3.0
# 168735  http://www.properati.com.ar/1bqtu_venta_depart...    NaN        2.0
# 168736  http://www.properati.com.ar/1bqtv_venta_casa_l...    NaN        NaN
# 168737  http://www.properati.com.ar/1bqtx_venta_depart...    NaN        2.0
# 168738  http://www.properati.com.ar/1bqty_venta_depart...    NaN        NaN
# 168739  http://www.properati.com.ar/1bqu0_venta_casa_s...    1.0        NaN

# %% [markdown]
# # Por ultimo vamos a buscar en internet cuando no haya ninguno de los 2 datos.

# %%
caracteristicas['webp'] = pd.Series(None, index=caracteristicas.index)

# %%
def chequearURL(x):
    
    if( pd.isnull(x[3]) ): return None
    if( not pd.isnull(x[4]) or not pd.isnull(x[5]) ): return None
    
    return buscarURL(x[3])
        
def buscarURL(x):
    
    req = Request(x)
    try:
        resp = urlopen(req, timeout=10)
    except URLError:
        print "Bad URL or timeout"
        return None

    resp_page = resp.read()
    
    return resp_page

# %%
caracteristicas['webp'] = caracteristicas.apply(chequearURL, axis=1)

# %%
caracteristicas.head(10)
# Out:
#                                               id  \
# 168728  77816f8811f96453c3a990de643fcf2d2659ac1b
# 168730  bed12005637a003d531a4dcc3aa5a1076787d3b1
# 168731  fb0007abeb74caed5c693783b617a1d1befa82df
# 168733  877ca74c858bc85dd3373eb265795c7fc3afc1e7
# 168734  ba7121c00740ba13447d21cda96286cead1615b7
# 168735  997b2405ded6af49f75ebe01ff168cfb82291223
# 168736  53162225dcf5fe8202e46f95aad3d6183f8cfe9d
# 168737  31dcf5ef4a9af6f1803aa8b998c9be95b223871f
# 168738  1bcd00c5319313fd70463337fce4d89bb73ebbbc
# 168739  08acdc231bd21c964a16a8af510c4bd444bb3f77
#
#                                               description  \
# 168728  SE TRATA DE UNA VIVIENDA MULTI FAMILIAR CONSIS...
# 168730  Impecable dpto 2 amb. a estrenar con detalles ...
# 168731  Sergio Villella Inmobiliaria presenta departam...
# 168733  LINDO DUPLEX DE 4 AMB: 3 DORM AMPLIOS, 2 BAÑOS...
# 168734  PH AL FRENTE CON ENTRADA INDEPENDIENTE Y ESPAC...
# 168735  Departamento de 2 ambientes a estrenar en comp...
# 168736  IMPORTANTE PROPIEDAD DESARROLLADA EN SOLO UNA ...
# 168737  Lindísimo departamento a Estrenar:   está ubic...
# 168738              Winterra S.A.Catamarca 1150CMCPSI5015
# 168739  Casa de 1 dormitorio, cocina comedor y baño. T...
#
#                                                     title  \
# 168728                                       Casa - Merlo
# 168730                        Departamento - San Fernando
# 168731   Ov. Lagos 600 - Venta departamento monoambiente.
# 168733                     Casa en Florida Belgrano-Oeste
# 168734                     PH 3 AMB. APTO CRÉDITO - Moron
# 168735        Departamento - Condominios Intercontinental
# 168736                                    Casa - La Plata
# 168737  BELLISIMO 2 AMBIENTES CON GRAN TERRAZA Y COCHERA.
# 168738           Departamento Lagoon Pilar Sector Serena!
# 168739                                   Casa - El Bolson
#
#                                             properati_url  rooms  ambientes  \
# 168728  http://www.properati.com.ar/1bqtk_venta_casa_m...    NaN        NaN
# 168730  http://www.properati.com.ar/1bqto_venta_depart...    NaN        2.0
# 168731  http://www.properati.com.ar/1bqtq_venta_depart...    NaN        1.0
# 168733  http://www.properati.com.ar/1bqts_venta_casa_f...    3.0        4.0
# 168734  http://www.properati.com.ar/1bqtt_venta_ph_mor...    4.0        3.0
# 168735  http://www.properati.com.ar/1bqtu_venta_depart...    NaN        2.0
# 168736  http://www.properati.com.ar/1bqtv_venta_casa_l...    NaN        NaN
# 168737  http://www.properati.com.ar/1bqtx_venta_depart...    NaN        2.0
# 168738  http://www.properati.com.ar/1bqty_venta_depart...    NaN        NaN
# 168739  http://www.properati.com.ar/1bqu0_venta_casa_s...    1.0        NaN
#
#                                                      webp
# 168728  <!DOCTYPE html>\n<!--[if lt IE 7 ]> <html clas...
# 168730                                               None
# 168731                                               None
# 168733                                               None
# 168734                                               None
# 168735                                               None
# 168736  <!DOCTYPE html>\n<!--[if lt IE 7 ]> <html clas...
# 168737                                               None
# 168738  <!DOCTYPE html>\n<!--[if lt IE 7 ]> <html clas...
# 168739                                               None

# %%
aux = caracteristicas[ pd.isnull(caracteristicas['webp']) == True ]
aux.count()
# Out:
# id               11340
# description      11340
# title            11340
# properati_url    11340
# rooms             6564
# ambientes         5593
# webp                 0
# dtype: int64

# %%
pickle.dump(caracteristicas,open("save12.p","wb"))
